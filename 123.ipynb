# %%
import torch


x = torch.rand([2000,3000])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.device('cuda:0')
# Out:
# device(type='cuda', index=0)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
x_cuda = x.to(device)

# %%
# %time (x - x + x * 10.0) ** 2
# Out:
# CPU times: total: 0 ns
# Wall time: 9 ms
# tensor([[7.7164e+01, 7.1674e+01, 4.1624e+00,  ..., 1.3476e+01, 3.5553e+01,
#          2.4775e+01],
#         [3.5092e+01, 2.1046e+01, 6.8549e+01,  ..., 8.8907e+01, 9.5533e+00,
#          4.4909e+01],
#         [3.2839e+01, 2.4817e+01, 2.4602e+01,  ..., 1.7816e+01, 7.7787e+01,
#          1.3375e+01],
#         ...,
#         [2.6702e+01, 7.9241e+01, 1.8447e+01,  ..., 2.2685e-03, 4.1483e+00,
#          3.3947e+01],
#         [1.1367e+01, 9.3221e+01, 8.6876e+01,  ..., 6.4241e-05, 9.4716e+00,
#          6.5655e+00],
#         [6.6259e+01, 3.2447e+01, 5.6164e+01,  ..., 4.9032e+01, 9.5517e+01,
#          1.2349e+00]])

# %%
# %time (x_cuda - x_cuda + x_cuda * 10.0) ** 2
# Out:
# CPU times: total: 46.9 ms
# Wall time: 49 ms
# tensor([[7.7164e+01, 7.1674e+01, 4.1624e+00,  ..., 1.3476e+01, 3.5553e+01,
#          2.4775e+01],
#         [3.5092e+01, 2.1046e+01, 6.8549e+01,  ..., 8.8907e+01, 9.5533e+00,
#          4.4909e+01],
#         [3.2839e+01, 2.4817e+01, 2.4602e+01,  ..., 1.7816e+01, 7.7787e+01,
#          1.3375e+01],
#         ...,
#         [2.6702e+01, 7.9241e+01, 1.8447e+01,  ..., 2.2685e-03, 4.1483e+00,
#          3.3947e+01],
#         [1.1367e+01, 9.3221e+01, 8.6876e+01,  ..., 6.4241e-05, 9.4716e+00,
#          6.5655e+00],
#         [6.6259e+01, 3.2447e+01, 5.6164e+01,  ..., 4.9032e+01, 9.5517e+01,
#          1.2349e+00]], device='cuda:0')

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Создание матрицы ошибок
cm = [[995, 5], [3, 998]]
